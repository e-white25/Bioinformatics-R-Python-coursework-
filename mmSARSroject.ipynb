# %% [markdown]
# Project
#
# 2.- How does SARS-Cov-02 infection alter transcripyional acitivity. Overall design: Comparative gene expression profiling analysis of RNA-seq data using 4 types (uninfected/infected, young/mid-aged) of isolated lung endothelial cells.
#
#  SRAID      | Age    |  Treatment |
# ------------|--------|------------|
# SRR24206824 | Young  | SARS-CoV-2
# SRR24206825 | MidAge | SARS-CoV-2
# SRR24206826 | Young  | PBS
# SRR24206827 | MidAge | PBS

# %%
# Run this box as this! It is installing the NCBIs SRA toolkit! This is how we will be dowloading data.
# !wget https://ftp-trace.ncbi.nlm.nih.gov/sra/sdk/3.1.0/sratoolkit.3.1.0-ubuntu64.tar.gz .
# !tar -vxzf sratoolkit.3.1.0-ubuntu64.tar.gz
# !chmod +777 sratoolkit.3.1.0-ubuntu64/bin/fastq-dump

# %%
### Start by downloading the data; subsampling the data to 5 M reads
# !sratoolkit.3.1.0-ubuntu64/bin/fastq-dump  -X 5000000 SRR24206824
# !sratoolkit.3.1.0-ubuntu64/bin/fastq-dump  -X 5000000 SRR24206825
# !sratoolkit.3.1.0-ubuntu64/bin/fastq-dump  -X 5000000 SRR24206826
# !sratoolkit.3.1.0-ubuntu64/bin/fastq-dump  -X 5000000 SRR24206827

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mv SRR24206824.fastq Young_SARScov2.fastq
# !mv SRR24206825.fastq Midage_SARScov2.fastq
# !mv SRR24206826.fastq Young_PBS.fastq
# !mv SRR24206827.fastq Midage_PBS.fastq

# %%
# !cp Young_SARScov2.fastq /content/drive/MyDrive/SARSdata
# !cp Midage_SARScov2.fastq /content/drive/MyDrive/SARSdata
# !cp Young_PBS.fastq /content/drive/MyDrive/SARSdata
# !cp Midage_PBS.fastq /content/drive/MyDrive/SARSdata

# %%
# m.mouse reference genome
# !wget ftp://ftp.ccb.jhu.edu/pub/infphilo/hisat2/data/mm10.tar.gz
# !tar -xzf mm10.tar.gz
# !cp mm10.tar.gz /content/drive/MyDrive/SARSdata /content/drive/MyDrive/SARSdata/

# %%
# Annotation Hash Table
# !wget https://ftp.ensembl.org/pub/release-102/gtf/mus_musculus/Mus_musculus.GRCm38.102.gtf.gz
# !gunzip Mus_musculus.GRCm38.102.gtf.gz

# %%
# !cp /content/Mus_musculus.GRCm38.102.gtf.gz /content/drive/MyDrive/SARSdata/

# %%
# FastQC libraries/tools
# !sudo apt-get install -y default-jre
# !java -version
# !wget https://www.bioinformatics.babraham.ac.uk/projects/fastqc/fastqc_v0.11.9.zip
# !unzip fastqc_v0.11.9.zip
# !chmod +x FastQC/fastqc

# %%
#checking read quality - htmls available in drive
# !./FastQC/fastqc --version
# !./FastQC/fastqc /content/drive/MyDrive/Young_PBS.fastq
# !./FastQC/fastqc /content/drive/MyDrive/SARSdata/Young_SARScov2.fastq
# !./FastQC/fastqc /content/drive/MyDrive/SARSdata/Midage_PBS.fastq
# !./FastQC/fastqc /content/drive/MyDrive/SARSdata/Midage_SARScov2.fastq

# %%
#trimming the primer/adapter region with poor quality
# !pip install cutadapt
# !cutadapt -h
# !cutadapt --cut 15 -q 28 -o /content/drive/MyDrive/SARSdata/Trimmed_Young_PBS.fastq /content/drive/MyDrive/SARSdata/Young_PBS.fastq
# !cutadapt --cut 15 -q 28 -o /content/drive/MyDrive/SARSdata/Trimmed_Young_SARScov2.fastq /content/drive/MyDrive/SARSdata/Young_SARScov2.fastq
# !cutadapt --cut 15 -q 28 -o /content/drive/MyDrive/SARSdata/Trimmed_Midage_SARScov2.fastq /content/drive/MyDrive/SARSdata/Midage_SARScov2.fastq
# !cutadapt --cut 15 -q 28 -o /content/drive/MyDrive/SARSdata/Trimmed_Midage_PBS.fastq /content/drive/MyDrive/SARSdata/Midage_PBS.fastq

# %%
#shortening read length for better alignment
# !cutadapt --cut 200 -o /content/drive/MyDrive/SARSdata/Final_MidagePBS.fastq /content/drive/MyDrive/SARSdata/Trimmed_Midage_PBS.fastq
# !cutadapt --cut 200 -o /content/drive/MyDrive/SARSdata/Final_MidageSARScov2.fastq /content/drive/MyDrive/SARSdata/Trimmed_Midage_SARScov2.fastq
# !cutadapt --cut 200 -o /content/drive/MyDrive/SARSdata/Final_YoungPBS.fastq /content/drive/MyDrive/SARSdata/Trimmed_Young_PBS.fastq
# !cutadapt --cut 200 -o /content/drive/MyDrive/SARSdata/Final_YoungSARScov2.fastq /content/drive/MyDrive/SARSdata/Trimmed_Young_SARScov2.fastq

# %%
# FastQC libraries/tools
# !sudo apt-get install -y default-jre
# !java -version
# !wget https://www.bioinformatics.babraham.ac.uk/projects/fastqc/fastqc_v0.11.9.zip
# !unzip fastqc_v0.11.9.zip
# !chmod +x FastQC/fastqc
# !./FastQC/fastqc /content/drive/MyDrive/SARSdata/Final_YoungSARScov2.fastq
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   default-jre-headless fonts-dejavu-core fonts-dejavu-extra
#   libatk-wrapper-java libatk-wrapper-java-jni libfontenc1 libxkbfile1 libxtst6
#   libxxf86dga1 openjdk-11-jre x11-utils
# Suggested packages:
#   mesa-utils
# The following NEW packages will be installed:
#   default-jre default-jre-headless fonts-dejavu-core fonts-dejavu-extra
#   libatk-wrapper-java libatk-wrapper-java-jni libfontenc1 libxkbfile1 libxtst6
#   libxxf86dga1 openjdk-11-jre x11-utils
# 0 upgraded, 12 newly installed, 0 to remove and 45 not upgraded.
# Need to get 3,720 kB of archives.
# After this operation, 12.7 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jre-headless amd64 2:1.11-72build2 [3,042 B]
# ...

# %%
# RNA sample alignments to genome
# !apt-get install hisat2

# %%
# !hisat2 -x /content/drive/MyDrive/SARSdata/mm10/genome -p 66 -U /content/drive/MyDrive/SARSdata/Final_MidagePBS.fastq -S /content/drive/MyDrive/SARSdata/Aln_Midage_PBS.sam

# %%
# !hisat2 -x /content/drive/MyDrive/SARSdata/mm10/genome -p 66 -U /content/drive/MyDrive/SARSdata/Final_MidageSARScov2.fastq -S /content/drive/MyDrive/SARSdata/Aln_Midage_SARScov2.sam

# %%
# !hisat2 -x /content/drive/MyDrive/SARSdata/mm10/genome -p 66 -U /content/drive/MyDrive/SARSdata/Final_YoungSARScov2.fastq -S /content/drive/MyDrive/SARSdata/Aln_Young_SARScov2.sam

# %%
# !hisat2 -x /content/drive/MyDrive/SARSdata/mm10/genome -p 66 -U /content/drive/MyDrive/SARSdata/Final_YoungPBS.fastq -S /content/drive/MyDrive/SARSdata/Aln_Young_PBS.sam

# %%
#subread: a general-purpose read aligner which can align both genomic DNA-seq and RNA-seq reads.
#It can also be used to discover genomic mutations including short indels and structural variants.
#documentation: https://subread.sourceforge.net/
# !apt-get install subread

# %%
# featureCounts - read summarization program that counts mapped reads for genomic features
# input: SAM/BAM files + an annotation file (including chromosomal coordinates of features)
# output: #s of reads assigned to features (or meta-features)
# !featureCounts -a /content/Mus_musculus.GRCm38.102.gtf -o counts.txt /content/drive/MyDrive/SARSdata/Aln_Midage_PBS.sam
# Out:
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v2.0.3
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 1 SAM file                                       ||
# ||                                                                            ||
# ||                           Aln_Midage_PBS.sam                               ||
# ||                                                                            ||
# ...

# %%
# !mv counts.txt MidagePBS.txt
# !cp MidagePBS.txt /content/drive/MyDrive/SARSdata/
# !mv counts.txt.summary MidagePBScounts.txt.summary
# !cp MidagePBScounts.txt.summary /content/drive/MyDrive/SARSdata/

# %%
# !featureCounts -a /content/Mus_musculus.GRCm38.102.gtf -o counts.txt /content/drive/MyDrive/SARSdata/Aln_Midage_SARScov2.sam
# Out:
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v2.0.3
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 1 SAM file                                       ||
# ||                                                                            ||
# ||                           Aln_Midage_SARScov2.sam                          ||
# ||                                                                            ||
# ...

# %%
# !mv counts.txt MidageSARScounts.txt
# !cp MidageSARScounts.txt /content/drive/MyDrive/SARSdata/
# !mv counts.txt.summary MidageSARScounts.txt.summary
# !cp MidageSARScounts.txt.summary /content/drive/MyDrive/SARSdata/

# %%
# !featureCounts -a /content/Mus_musculus.GRCm38.102.gtf -o counts.txt /content/drive/MyDrive/SARSdata/Aln_Young_SARScov2.sam
# Out:
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v2.0.3
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 1 SAM file                                       ||
# ||                                                                            ||
# ||                           Aln_Young_SARScov2.sam                           ||
# ||                                                                            ||
# ...

# %%
# !mv counts.txt YoungSARScounts.txt
# !cp YoungSARScounts.txt /content/drive/MyDrive/SARSdata/
# !mv counts.txt.summary YoungSARScounts.txt.summary
# !cp YoungSARScounts.txt.summary /content/drive/MyDrive/SARSdata/

# %%
# !featureCounts -a /content/Mus_musculus.GRCm38.102.gtf -o counts.txt /content/drive/MyDrive/SARSdata/Aln_Young_PBS.sam
# Out:
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v2.0.3
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 1 SAM file                                       ||
# ||                                                                            ||
# ||                           Aln_Young_PBS.sam                                ||
# ||                                                                            ||
# ...

# %%
# !mv counts.txt YoungPBScounts.txt
# !cp YoungPBScounts.txt /content/drive/MyDrive/SARSdata/
# !mv counts.txt.summary YoungPBScounts.txt.summary
# !cp YoungPBScounts.txt.summary /content/drive/MyDrive/SARSdata/

# %%
from google.colab import files
# files.download('MidagePBScounts.txt')
files.download('MidageSARScounts.txt')
files.download('YoungSARScounts.txt')
files.download('YoungPBScounts.txt')
